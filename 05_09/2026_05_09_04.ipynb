# %% [markdown]
# <a href="https://colab.research.google.com/github/roberthsu2003/__2026_05_09_chihlee_python__/blob/main/05_09/2026_05_09_04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## if

# %%
5 > 3
3 >= 5
5 == 5
5 != 5
# Out:
# False

# %%
age = 17
if age >= 18:
  print("你滿18了!")
  print("你可以考駕照")
else:
  print("你還沒滿18!")
  print("你不可以考駕照")
print("應用程式結束")
# Out:
# 你還沒滿18!
# 你不可以考駕照
# 應用程式結束

# %%
#學生總分為300
#有些學生可以加分5%
scores:int|float = int(input("請輸入學生分數(最高300分)")) #:int,typehint,型別提示
is_add:str = input("學生是否符合加分條件?(y,n)")

if is_add == "y":
  scores = scores * 1.05

print("學生分數是:", round(scores, 2))
# Out:
# 請輸入學生分數(最高300分)250
# 學生是否符合加分條件?(y,n)y
# 學生分數是: 262.5

# %%
#學生總分為300
#有些學生可以加分5%
#如果加分超過300,就以300分為準
scores:int|float = int(input("請輸入學生分數(最高300分)")) #:int,typehint,型別提示
is_add:str = input("學生是否符合加分條件?(y,n)")

if is_add == "y":
  scores = scores * 1.05
  if scores > 300: #巢狀判斷
    scores = 300

print("學生分數是:", round(scores, 2))
# Out:
# 請輸入學生分數(最高300分)290
# 學生是否符合加分條件?(y,n)y
# 學生分數是: 300
