# %%
import numpy as np
import pandas as pd

data = pd.Series(np.random.randn(9),
                index=[['a', 'a', 'a', 'b', 'b', 'c', 'c', 'd', 'd'],
                       [1, 2, 3, 1, 2, 3, 1, 2, 3]])
data
# Out:
# a  1   -1.108571
#    2   -3.677450
#    3   -0.050977
# b  1    0.562698
#    2   -0.763657
# c  3    2.627235
#    1   -0.397777
# d  2    1.893875
#    3   -0.332090
# dtype: float64

# %%
data1 = data.unstack()
data1
# Out:
#           1         2         3
# a -1.108571 -3.677450 -0.050977
# b  0.562698 -0.763657       NaN
# c -0.397777       NaN  2.627235
# d       NaN  1.893875 -0.332090

# %%
data1.stack()
# Out:
# a  1   -1.108571
#    2   -3.677450
#    3   -0.050977
# b  1    0.562698
#    2   -0.763657
#    3         NaN
# c  1   -0.397777
#    2         NaN
#    3    2.627235
# d  1         NaN
#    2    1.893875
#    3   -0.332090
# dtype: float64
