# %%
import numpy as np
from numpy import ndarray
import pandas as pd
from pandas import DataFrame

#scores:ndarray | None = None # 學生的分數
#scores_df:DataFrame | None = None # 學生分數的DataFrame

scores:ndarray = np.random.randint(40, 101, size=(50, 5))
scores_df:DataFrame = pd.DataFrame(scores,            
            columns=['國文', '英文', '數學', '地理', '歷史'],
            index=range(1,51))

names_df:DataFrame = pd.read_csv('students.csv')
scores_df[['姓名','性別']] = names_df[['姓名','性別']].head(n=50).values
scores_df = scores_df[['姓名', '性別','國文', '英文', '數學', '地理', '歷史']]
#選取欄
scores_df[['姓名','國文']]
#選取列
scores_df.iloc[5]
scores_df.iloc[5:10]
# Out:
#      姓名 性別  國文  英文  數學  地理  歷史
# 6   朱冠霖  男  63  43  72  50  87
# 7   謝欣蓉  女  90  91  90  50  94
# 8   羅淑芬  女  74  48  50  53  59
# 9   許美慧  女  42  77  75  62  98
# 10  廖志豪  男  54  49  46  71  98

# %%
scores_df[scores_df['姓名'] == '許美慧']
scores_df[scores_df['國文'] < 60]
scores_df.query("性別 == '女' and 國文 < 60 ")
# Out:
#      姓名 性別  國文  英文  數學  地理  歷史
# 9   許美慧  女  42  77  75  62  98
# 30  楊靜宜  女  45  95  84  47  46
# 32  蕭怡伶  女  55  41  64  47  69
# 39  彭美慧  女  57  63  95  57  41
# 41  許淑芬  女  44  79  84  45  60
# 43  吳雅萍  女  50  75  84  86  78
# 47  周美玲  女  54  46  80  63  94

# %%
scores_df["總分"] = scores_df[['國文', '英文', '數學', '地理', '歷史']].sum(axis=1)
scores_df["平均"] = scores_df[['國文', '英文', '數學', '地理', '歷史']].mean(axis=1)
scores_df["排名"] = scores_df["總分"].rank(ascending=False,method='min')
scores_df.sort_values(by='排名')
# Out:
#      姓名 性別   國文  英文   數學   地理   歷史   總分    平均    排名
# 40  劉靜芬  女   88  94   96   75   76  429  85.8   1.0
# 31  曾靜儀  女   86  81   73   89   91  420  84.0   2.0
# 7   謝欣蓉  女   90  91   90   50   94  415  83.0   3.0
# 37  呂怡靜  女   90  57  100   90   76  413  82.6   4.0
# 42  邱裕豪  男  100  62   87   82   79  410  82.0   5.0
# 13  蘇雅婷  女   94  80   75   70   84  403  80.6   6.0
# 15  王婉茹  女   83  76   92   93   59  403  80.6   6.0
# 38  邱宗翰  男   55  91   99   90   63  398  79.6   8.0
# 48  劉婉婷  女   74  83   91   94   56  398  79.6   8.0
# 27  江雅琪  女   99  82   43   72  100  396  79.2  10.0
# 1   劉彥宏  男   63  90   72   91   76  392  78.4  11.0
# 21  蘇彥宏  男   93  68   96   75   58  390  78.0  12.0
